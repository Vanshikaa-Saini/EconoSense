# %%
from config import input_path
import pandas as pd

# %%
df_raw = pd.read_spss(input_path)

print(df_raw.head())
# Out:
#   survey_name    year    fsu sector            state nss_region district  \
# 0        HCES  2022.0  65556  rural  Jammu & Kashmir        013       11
# 1        HCES  2022.0  65556  rural  Jammu & Kashmir        013       11
# 2        HCES  2022.0  65556  rural  Jammu & Kashmir        013       11
# 3        HCES  2022.0  65556  rural  Jammu & Kashmir        013       11
# 4        HCES  2022.0  65556  rural  Jammu & Kashmir        013       11
#
#   stratum sub_stratum panel  ... b1q1pt7 b1q1pt10 b1q1pt11 b1q1pt12  \
# 0      13          01     1  ...       2                 2       01
# 1      13          01     1  ...       2                 2       01
# 2      13          01     1  ...       2                 2       01
# 3      13          01     1  ...       2                 2       01
# 4      13          01     1  ...       2                 2       01
#
#   questionaire_no level b13pt1q2 b13pt1q3 b13pt1q4     mult
# ...

# %%
list(df_raw.columns)
# Out:
# ['survey_name',
#  'year',
#  'fsu',
#  'sector',
#  'state',
#  'nss_region',
#  'district',
#  'stratum',
#  'sub_stratum',
#  'panel',
#  'sub_sample',
#  'fod_subregion',
#  'b1q1pt7',
#  'b1q1pt10',
#  'b1q1pt11',
#  'b1q1pt12',
#  'questionaire_no',
#  'level',
#  'b13pt1q2',
#  'b13pt1q3',
#  'b13pt1q4',
#  'mult']

# %%
df_raw = df_raw.rename(
    columns={
        'b13pt1q2':'item_code',
        'b13pt1q3':'quantity',
        'b13pt1q4':'value',
    }
)

# %%
df = df_raw[df_raw['item_code']=='370'].copy() # electric fan

# %%
# scatter plot quantity vs price using plotly
import plotly.express as px 
fig = px.scatter(df, x='value', y='quantity', title='Quantity vs Price')
fig.show()
